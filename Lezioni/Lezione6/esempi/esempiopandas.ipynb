# %%
import esempiopandas1
df = esempiopandas1.df

# %%
print(df)

# %%
display(df)

# %%
sorted = df.sort_values(by='Quantita', ascending=False)

# %%
sorted.loc[0, 'Prodotto']

# %%
display(sorted)

# %%
sorted.iloc[0]['Prodotto']
